# %% [markdown]
# # Exploratory Data Analysis
#
# **Objective:** Analyze failure balance and relationships with asset condition, operations, maintenance, and weather.
#
# ## Business Context
# PowerGrid needs to identify assets at risk of grid failure and prioritize proactive maintenance.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd().resolve().parents[0]
sys.path.append(str(ROOT/'src'))
print(ROOT)

# %% [markdown]
# ## Analysis
# Run the corresponding modular script in `src/` and inspect the generated outputs. Interpret each result in business terms rather than reporting metrics alone.

# %%
import pandas as pd
df=pd.read_excel(ROOT/'data/raw/original_dataset.xlsx')
df.head()

# %% [markdown]
# ## Conclusion
# Document the actual findings from the executed cells and cite the generated figures/tables in the final report.
